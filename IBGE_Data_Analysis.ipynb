# %% [markdown]
# <a href="https://colab.research.google.com/github/Deziderio55/Ap2/blob/main/IBGE_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/br_ibge_censo_2022_alfabetizacao_grupo_idade_sexo_raca (1).csv')

# Primeiras 5 linhas dos dados
print("\n=== PRIMEIRAS 5 LINHAS ===")
print(df.head())
# Out:
# === PRIMEIRAS 5 LINHAS ===
#    id_municipio  cor_raca      sexo   grupo_idade      alfabetizacao  \
# 0       1100023  Indígena    Homens  15 a 19 anos  Não alfabetizadas
# 1       1100262   Amarela  Mulheres  15 a 19 anos  Não alfabetizadas
# 2       1101005   Amarela  Mulheres  15 a 19 anos  Não alfabetizadas
# 3       1101435   Amarela  Mulheres  15 a 19 anos  Não alfabetizadas
# 4       1101435  Indígena  Mulheres  15 a 19 anos  Não alfabetizadas
#
#    populacao
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
# Remove espaços invisíveis que quebram comparações
df['alfabetizacao'] = df['alfabetizacao'].str.strip()

# Confirma os valores únicos após limpeza
print(df['alfabetizacao'].value_counts())
# Out:
# alfabetizacao
# Não alfabetizadas    389900
# Alfabetizadas        389900
# Name: count, dtype: int64

# %%
por_alfabetizacao = (
    df.groupby('alfabetizacao')
    .size()
    .reset_index(name='total_registros')
)

print(por_alfabetizacao)
# Out:
#        alfabetizacao  total_registros
# 0      Alfabetizadas           389900
# 1  Não alfabetizadas           389900

# %%
por_alfabetizacao = (
    df.groupby('alfabetizacao')['populacao']
    .sum()
    .reset_index(name='total_populacao')
)

print(por_alfabetizacao)
# Out:
#        alfabetizacao  total_populacao
# 0      Alfabetizadas      151538765.0
# 1  Não alfabetizadas       11403249.0

# %%
raca_alfa = (
    df.groupby(['alfabetizacao', 'cor_raca'])['populacao']
    .sum()
    .reset_index(name='total_populacao')
    .sort_values(['alfabetizacao', 'total_populacao'], ascending=[True, False])
)

print(raca_alfa)
# Out:
#        alfabetizacao  cor_raca  total_populacao
# 1      Alfabetizadas    Branca       68230928.0
# 3      Alfabetizadas     Parda       65953388.0
# 4      Alfabetizadas     Preta       15927141.0
# 0      Alfabetizadas   Amarela         735125.0
# 2      Alfabetizadas  Indígena         692183.0
# 8  Não alfabetizadas     Parda        6361627.0
# 6  Não alfabetizadas    Branca        3092991.0
# 9  Não alfabetizadas     Preta        1797379.0
# 7  Não alfabetizadas  Indígena         132451.0
# 5  Não alfabetizadas   Amarela          18801.0

# %%
sexo_alfa = (
    df.groupby(['alfabetizacao', 'sexo'])['populacao']
    .sum()
    .reset_index(name='total_populacao')
)

print(sexo_alfa)
# Out:
#        alfabetizacao      sexo  total_populacao
# 0      Alfabetizadas    Homens       72195961.0
# 1      Alfabetizadas  Mulheres       79342804.0
# 2  Não alfabetizadas    Homens        5865255.0
# 3  Não alfabetizadas  Mulheres        5537994.0

# %%
pivot = df.pivot_table(
    index='cor_raca',
    columns='alfabetizacao',
    values='populacao',   # Somar a população
    aggfunc='sum',
    fill_value=0             # grupos sem registros aparecem como 0
)

print(pivot)
# Out:
# alfabetizacao  Alfabetizadas  Não alfabetizadas
# cor_raca
# Amarela             735125.0            18801.0
# Branca            68230928.0          3092991.0
# Indígena            692183.0           132451.0
# Parda             65953388.0          6361627.0
# Preta             15927141.0          1797379.0

# %%
proporcao = pivot.div(pivot.sum(axis=1), axis=0).round(3) * 100
print(proporcao)
# Out:
# alfabetizacao  Alfabetizadas  Não alfabetizadas
# cor_raca
# Amarela                 97.5                2.5
# Branca                  95.7                4.3
# Indígena                83.9               16.1
# Parda                   91.2                8.8
# Preta                   89.9               10.1
